# %%
# Final Project : Spotify Analysis Dataset 2025

# %%
# Introduction 
This project explores user behavior on Spotify to understand why some users stop using the service, also known as churn. Using a dataset with over 8,000 records and 12 features, I performed a full data analysis process — starting with data cleaning, followed by exploratory data analysis (EDA), visualizations, and insight generation.

The goal is to identify patterns and factors that may influence user churn, such as session length, total streams, or user demographics. By analyzing these trends, we can suggest ways Spotify might improve user retention and engagement.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Kavery\Desktop\spotify_churn_dataset.csv')

# %%
df.shape  # Rows and columns
# Out:
# (8000, 12)

# %%
df.dtypes  # Data types
# Out:
# user_id                    int64
# gender                    object
# age                        int64
# country                   object
# subscription_type         object
# listening_time             int64
# songs_played_per_day       int64
# skip_rate                float64
# device_type               object
# ads_listened_per_week      int64
# offline_listening          int64
# is_churned                 int64
# dtype: object

# %%
df.head()  # First few rows
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.info()  # Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB

# %%
df.describe(include='all')  # Stats for all columns
# Out:
#            user_id gender          age country subscription_type  \
# count   8000.00000   8000  8000.000000    8000              8000
# unique         NaN      3          NaN       8                 4
# top            NaN   Male          NaN      AU           Premium
# freq           NaN   2691          NaN    1034              2115
# mean    4000.50000    NaN    37.662125     NaN               NaN
# std     2309.54541    NaN    12.740359     NaN               NaN
# min        1.00000    NaN    16.000000     NaN               NaN
# 25%     2000.75000    NaN    26.000000     NaN               NaN
# 50%     4000.50000    NaN    38.000000     NaN               NaN
# 75%     6000.25000    NaN    49.000000     NaN               NaN
# max     8000.00000    NaN    59.000000     NaN               NaN
#
#         listening_time  songs_played_per_day    skip_rate device_type  \
# count      8000.000000           8000.000000  8000.000000        8000
# ...

# %%
df.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
df.dropna(inplace=True)  # or use df.fillna()

# %%
df.drop_duplicates(inplace=True)

# %%
df_filtered = df[df['country'] == 'India']

# %%
import seaborn as sns

# %%
sns.histplot(df['age'], bins=20, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
import seaborn as sns

# %%
print(df.columns.tolist())
# Out:
# ['user_id', 'gender', 'age', 'country', 'subscription_type', 'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type', 'ads_listened_per_week', 'offline_listening', 'is_churned']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))

# %%
# Replace with actual column names from your dataset
x_col = 'Churn_Status'  # or whatever you found
y_col = 'avg_session_length'

# %%
plt.figure(figsize=(8, 5))

# %%
plt.title(f'{y_col} by {x_col}')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.show()

# %%
x_col = 'churn'

# %%
y_col = 'avg_session_length'

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))

# %%
x_col = 'Churn_Status'

# %%
y_col = 'SessionLengthAvg'

# %%
print(x_col in df.columns)
# Out:
# False

# %%
print(y_col in df.columns)
# Out:
# False

# %%
['user_id', 'gender', 'country', 'session_duration', 'churn_flag', 'total_streams', ...]
# Out:
# ['user_id',
#  'gender',
#  'country',
#  'session_duration',
#  'churn_flag',
#  'total_streams',
#  Ellipsis]

# %%
plt.figure(figsize=(8,5))

# %%
plt.title('Churn Rate by Gender')
# Out:
# Text(0.5, 1.0, 'Churn Rate by Gender')

# %%
plt.show()

# %%
plt.figure(figsize=(10,6))

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.show()

# %%
plt.figure(figsize=(8,5))

# %%
sns.histplot(df['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))

# %%
print(df.columns)
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))

# %%
sns.boxplot(x='user_id', y='offline_listening', data=df)
# Out:
# <Axes: xlabel='user_id', ylabel='offline_listening'>

# %%
plt.show()

# %%
plt.figure(figsize=(8,5))

# %%
sns.scatterplot(x='songs_played_per_day', y='listening_time', hue='is_churned', data=df)
# Out:
# <Axes: xlabel='songs_played_per_day', ylabel='listening_time'>

# %%
df['is_churned'] = df['is_churned'].astype('category')

# %%
df['listening_time'] = pd.to_numeric(df['listening_time'], errors='coerce')

# %%
# insights 
1) Younger users 13 to 25 show higher churn rates.
2) Free users churn more than premium or family users.
3) high ship rate and ad exposure correlate with churn.
4) Desktop users churn more than mobile users.

# Conclusion
    Spotify should focus on increasing engagement among young and free-tier users to reduce churn.
